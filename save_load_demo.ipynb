# %%
# https://www.tensorflow.org/tutorials/keras/save_and_load
import numpy as np
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
import tensorflow as tf

# %%
# https://www.tensorflow.org/api_docs/python/tf/keras/layers/Embedding
# https://www.tensorflow.org/guide/keras/serialization_and_saving
embedding_layer = tf.keras.layers.Embedding(5, 3)
model = tf.keras.Sequential([embedding_layer], name="seq")
# model.compile()

model.layers[0].get_weights()
# Out:
# [array([[ 0.04608014,  0.00628531,  0.03983678],
#         [ 0.0309006 ,  0.01166091, -0.03537776],
#         [-0.0214542 , -0.02625129,  0.04978884],
#         [-0.01436626, -0.02549051,  0.0103106 ],
#         [-0.03749027, -0.02518125,  0.01701752]], dtype=float32)]

# %%
model.built
# Out:
# True

# %%
model.summary()
# Out:
# Model: "seq"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_7 (Embedding)     (None, None, 3)           15
#
# =================================================================
# Total params: 15 (60.00 Byte)
# Trainable params: 15 (60.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.save('save/model.keras')

# %%
model2 = tf.keras.models.load_model('save/model.keras')

# %%
model2.layers[0].get_weights()
# Out:
# [array([[-0.02913535,  0.03310027, -0.044678  ],
#         [ 0.00198274,  0.03921734, -0.04906237],
#         [-0.04340104, -0.01020247, -0.01518687],
#         [-0.04369183, -0.00679272,  0.01790785],
#         [-0.04480213,  0.02220296,  0.01493319]], dtype=float32)]
